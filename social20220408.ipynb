# %%
import requests
from bs4 import BeautifulSoup

# 특정 URL에 접속하는 요청(Reqeust) 객체를 생성합니다.
request = requests.get("http://www.cu.ac.kr/plaza/notice/notice")

# 접속한 이후의 웹 사이트 소스코드를 추출합니다.
html = request.text

# HTML 소스코드를 파이썬 객체로 변환합니다.
soup = BeautifulSoup(html, 'html.parser')

# <a> 태그 포함하는 요소를 추출합니다.
links = soup.select('td > a')

# 모든 링크에 하나씩 접근합니다.
for link in links:
    # 링크가 href 속성을 가지고 있다면
    if link.has_attr('href') & ~link.has_attr('class'):
        # href 속성의 값으로 notice라는 문자를 포함되어 있다면
        if link.get('href').find('notice') != -1:
            print(link.text.strip())
# Out:
# 2022년 특수외국어능력평가 실시 안내
# 2022학년도 제2차 생명윤리위원회 정규심의 일정 안내
# 2022학년도 생명윤리위원회 연구자 및 종사자 대상 교육 실시 안내
# 2022년 한국장학재단 다문화 및 탈북학생 멘토링 장학금 멘토 모집 안내
# [혁신] 창의융합 3D프린터 후가공 교육 프로그램 신청 안내[비교과]
# 2022년 경산시 청년예비창업가육성사업 (예비)창업자 모집 공고
# 대구 문학과 예술, 책으로 만나다
# [SW] 2022년 제1차 SW융합특강 신청 안내
# 체력증진센터 비교과 프로그램  'Monday 세미나' 안내
# [이벤트] DCU 평생학습 플랫폼 이름을 부탁해! (기간연장)
# [혁신] 창의융합 3D프린터 심화교육 프로그램 신청 안내[비교과]
# 2022 삼성전자서비스 CS 산학 인턴십 프로그램 신청 안내
# [혁신]교수학습지원센터 학습지원 서포터즈 안내(장학금)(스텔라)
# [혁신] 2022-1학기 학생 교육혁신단 모집 공고(기간연장)
# [혁신] 창의융합 아두이노 온라인 기초교육[비교과]
# [혁신] 창의융합 3D프린터 모델링 온라인 기초교육[비교과]
# 교내 조경수목 병충해방제 작업 안내
# 제1학생식당 금요일 운영시간 변경 안내
# 2022학년도 1학기 會(회)지원사업 공모 안내
# 누구나 만들 수 있는 VLOG 영상편집 Premire Pro 교육
# 중앙도서관 스터디룸 이용 안내
# [혁신] 유니티 엔진 입문자를 위한 유니티 기초 및 UI/UX 디자인 교육 ..
# [SW] 2022학년도 SW창업특강(4차) 신청 안내
# 2022-1학기 대학생을 위한 통일 강좌 [회복적 평화와 북한사회문화의 이해..
# 「대구가톨릭대학교 학칙」 개정(안) 공고
# 국비 무료 여성교육생 모집(메타버스 콘텐츠 개발을 위한 드론 운용 및 3D모..
# 2022년도 SW창업특강(3차) 신청 안내
# [혁신]2022-1 맞춤형 학습지원 특강 안내(스텔라)
# 2022-1차 응급처치 및 심폐소생술 교육 시행 및 이수 현황 확인방법 안내
# 2022-1차 성인지 교육 시행 안내

# %%
import requests
from bs4 import BeautifulSoup

# 특정 URL에 접속하는 요청(Request) 객체를 생성.
request = requests.get("http://www.cu.ac.kr/plaza/notice/notice")

# 접속한 이후의 웹 사이트 소스코드를 추출.
html = request.text

# HTML 소스코드를 파이썬 객체로 변환.
soup = BeautifulSoup(html, 'html.parser')

# <tr> 태그를 포함하는 요소를 추출
trs = soup.select('div.board_list tr')
print(len(trs))

# 모든 tr에 하나씩 접근.
board_data = []

for tr in trs:
    tds = tr.find_all('td')

    # 테이블 헤더는 스킵합니다.
    if len(tds) == 0:
        continue

    board_data.append(
        [tds[1].text.strip(), 
        tds[3].text.strip(), 
        tds[4].text.strip(), 
        tds[5].text.strip()])

import pandas as pd
board_df = pd.DataFrame(board_data, columns = ['title', 'writer', 'date', 'viewers'])
board_df
# Out:
# 35
#                                            title     writer        date  \
# 0                             2022학년도 ROTC 모집 안내    학생군사교육단  2022/04/08
# 1                      2022-1학기 중앙도서관 이용시간 변경 안내    이용자서비스팀  2022/04/01
# 2         2022 대구가톨릭대학교 전국 중·고등학교 디자인·미술 실기대회 안내   디자인대학행정실  2022/03/28
# 3                         2022학년도 1학기 스쿨버스 운행 안내      학생지원팀  2022/02/10
# 4                          2022년 특수외국어능력평가 실시 안내    외국어교육센터  2022/04/07
# 5                 2022학년도 제2차 생명윤리위원회 정규심의 일정 안내       윤리센터  2022/04/07
# 6          2022학년도 생명윤리위원회 연구자 및 종사자 대상 교육 실시 안내       윤리센터  2022/04/07
# 7       2022년 한국장학재단 다문화 및 탈북학생 멘토링 장학금 멘토 모집 안내    사회과학연구소  2022/04/07
# 8         [혁신] 창의융합 3D프린터 후가공 교육 프로그램 신청 안내[비교과]    이용자서비스팀  2022/04/07
# 9            2022년 경산시 청년예비창업가육성사업 (예비)창업자 모집 공고     창업보육센터  2022/04/07
# 10                            대구 문학과 예술, 책으로 만나다    이용자서비스팀  2022/04/05
# 11                   [SW] 2022년 제1차 SW융합특강 신청 안내  SW중심대학사업단  2022/04/06
# 12              체력증진센터 비교과 프로그램  'Monday 세미나' 안내     체력증진센터  2022/04/06
# 13            [이벤트] DCU 평생학습 플랫폼 이름을 부탁해! (기간연장)        홍보팀  2022/03/25
# 14          [혁신] 창의융합 3D프린터 심화교육 프로그램 신청 안내[비교과]    이용자서비스팀  2022/04/06
# 15             2022 삼성전자서비스 CS 산학 인턴십 프로그램 신청 안내   현장실습지원센터  2022/03/24
# 16           [혁신]교수학습지원센터 학습지원 서포터즈 안내(장학금)(스텔라)   교수학습지원센터  2022/04/05
# 17            [혁신] 2022-1학기 학생 교육혁신단 모집 공고(기간연장)      교육혁신팀  2022/03/28
# 18                  [혁신] 창의융합 아두이노 온라인 기초교육[비교과]    이용자서비스팀  2022/04/05
# 19             [혁신] 창의융합 3D프린터 모델링 온라인 기초교육[비교과]    이용자서비스팀  2022/04/05
# 20                           교내 조경수목 병충해방제 작업 안내     캠퍼스관리팀  2022/04/05
# 21                         제1학생식당 금요일 운영시간 변경 안내      총무행정팀  2022/04/05
# 22                    2022학년도 1학기 會(회)지원사업 공모 안내      학생지원팀  2022/04/05
# 23          누구나 만들 수 있는 VLOG 영상편집 Premire Pro 교육    이용자서비스팀  2022/04/05
# 24                              중앙도서관 스터디룸 이용 안내    이용자서비스팀  2022/04/05
# 25  [혁신] 유니티 엔진 입문자를 위한 유니티 기초 및 UI/UX 디자인 교육 ..    이용자서비스팀  2022/04/05
# 26                 [SW] 2022학년도 SW창업특강(4차) 신청 안내  SW중심대학사업단  2022/04/04
# 27  2022-1학기 대학생을 위한 통일 강좌 [회복적 평화와 북한사회문화의 이해..     다문화연구원  2022/04/01
# 28                        「대구가톨릭대학교 학칙」 개정(안) 공고      혁신전략팀  2022/04/01
# 29  국비 무료 여성교육생 모집(메타버스 콘텐츠 개발을 위한 드론 운용 및 3D모..   창의도시연구센터  2022/04/01
# 30                       2022년도 SW창업특강(3차) 신청 안내  SW중심대학사업단  2022/04/01
# 31                [혁신]2022-1 맞춤형 학습지원 특강 안내(스텔라)   교수학습지원센터  2022/04/01
# 32    2022-1차 응급처치 및 심폐소생술 교육 시행 및 이수 현황 확인방법 안내   교원양성지원센터  2022/04/01
# 33                          2022-1차 성인지 교육 시행 안내   교원양성지원센터  2022/04/01
#
#    viewers
# 0        8
# 1     2163
# 2     2029
# 3    12342
# 4      183
# 5      101
# 6       98
# 7      222
# 8      183
# 9      139
# 10     455
# 11     699
# 12     729
# 13    2003
# 14     344
# 15    2332
# 16    1049
# 17    2528
# 18     379
# 19     292
# 20     179
# 21     339
# 22     552
# 23     421
# 24     261
# 25     277
# 26     502
# 27     758
# 28    1587
# 29     528
# 30     703
# 31    1278
# 32     802
# 33     582
